# %% [markdown]
# # AFC - Travail à faire
#
# ## Mastère ESD - Introduction au Machine Learning

# %% [markdown]
# ## Catégories socio-professionnelles dans les régions française
#
# Nous disposons sur cette [page](https://www.insee.fr/fr/statistiques/1893185) de la répartition de la population active de 25 à 54 ans selon la catégorie socioprofessionnelle et la position vis à vis de l’emploi, par commune et département (de 1968 à 2014). Après quelques manipulations, vous pouvez récupérer directement [le fichier 1968](regions-csp-1968.csv) et [le fichier 2014](regions-csp-2014.csv), par régions.
#
# Les codes ci-dessous vous montrent comment les importer.

# %%
import pandas

regions = pandas.read_csv("regions-csp-1968.csv")
regions.head()
# Out:
#                     Région  Agriculteurs Actifs ayant un emploi RP1968  \
# 0            Île-de-France                                       13652
# 1      Centre-Val de Loire                                       73128
# 2  Bourgogne-Franche-Comté                                       85284
# 3                Normandie                                      113008
# 4          Hauts-de-France                                       86004
#
#    Agriculteurs Chômeurs RP1968  \
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
#
#    Artisans, commerçants, chefs d'entreprise Actifs ayant un emploi RP1968  \
# 0                                             221520
# 1                                              53572
# 2                                              61824
# 3                                              69388
# ...

# %%
import pandas

regions = pandas.read_csv("regions-csp-2014.csv")
regions.head()
# Out:
#                     Région  Agriculteurs Actifs ayant un emploi RP2014  \
# 0            Île-de-France                                 3373.297125
# 1      Centre-Val de Loire                                13731.136316
# 2  Bourgogne-Franche-Comté                                20314.763142
# 3                Normandie                                19265.892020
# 4          Hauts-de-France                                17767.070961
#
#    Agriculteurs Chômeurs RP2014  \
# 0                    195.053895
# 1                    164.913387
# 2                    177.683361
# 3                    162.360831
# 4                    184.594238
#
#    Artisans, commerçants, chefs d'entreprise Actifs ayant un emploi RP2014  \
# 0                                      203747.801541
# 1                                       47577.256270
# 2                                       53729.925925
# 3                                       61807.703240
# ...

# %% [markdown]
# ### Travail à faire
#
# - Réaliser une AFC sur le croisement entre la catégorie socioprofessionnelle et la région
#     - pour 1968
#     - pour 2014
# - A l’aide des outils à votre disposition (tableaux et graphiques),
#     - Décrire la situation pour chaque année,
#     - Comparer les deux situations
